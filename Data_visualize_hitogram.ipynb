# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import itertools

# %%
df = pd.read_excel(r'wellMa1.xlsx')

# %%
print(df.head())
# Out:
#          Well_name     Depth  Gamma_Ray  Spontaneous_Potential  \
# 0  01_VILLADEGNA1.  440.0276       27.1                51.1684
# 1  01_VILLADEGNA1.  440.1800       25.5                51.1684
# 2  01_VILLADEGNA1.  440.3324       23.6                50.9275
# 3  01_VILLADEGNA1.  440.4848       21.1                50.9275
# 4  01_VILLADEGNA1.  440.6372       22.1                50.6865
#
#    Neutron_Porosity Litologia  Litologia_Code
# 0            0.3224   Argille               1
# 1            0.3372   Argille               1
# 2            0.3612   Argille               1
# 3            0.3956   Argille               1
# 4            0.4218   Argille               1

# %%
#df1 = df[(df['Gamma_Ray'] > 15) & (df['Neutron_Porosity'] > 0.1) & (df['Spontaneous_Potential'] > 10)] # Add a filter to remove displaying 0 Gamma Ray values

# %%
sns.distplot(df['Neutron_Porosity'], bins='auto', kde=True, color = "blue")

# %%
sns.distplot(df['Gamma_Ray'], bins='auto', kde=True, color = "blue")

# %%
df2 = df[(df['Spontaneous_Potential'] > 7)] # & (df['Spontaneous_Potential'] > 10)]
sns.distplot(df2['Spontaneous_Potential'], bins='auto', kde=True, color = "blue")

# %%
facies_colors = ['#F4D03F', '#F5B041', '#DC7633','#6E2C00', '#1B4F72', '#2E86C1', '#AED6F1', '#A569BD']
labels = ['Argille', 'Calcari', 'Marne', 'Calcari dolomitizzati', 'Dolomie']#, 'Dolomie calcaree e anidriti', 'Argilloscisti', 'Dolomia e anidrite']

# %%
import seaborn as sns
sns.set()
sns.pairplot(df.drop(['Well_name', 'Litologia_Code', 'Depth'],axis=1),
             hue='Litologia', palette=facies_colors,
             hue_order=list(labels))
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:447: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# C:\Users\HP\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:447: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.

# %%
import numpy as np

# %%
# Prepare data
x_var = 'Gamma_Ray'
groupby_var = 'Litologia'
newDF = (df['Litologia']=='Argille')
df_agg = df.loc[:, [x_var, groupby_var]].groupby(groupby_var)
vals = [df[x_var].values.tolist() for i, df in df_agg]
plt.rcParams['axes.facecolor'] = 'grey'
# Draw
plt.figure(figsize=(16,9), dpi= 80)
colors = [plt.cm.Spectral(i/float(len(vals)-1)) for i in range(len(vals))]
n, bins, patches = plt.hist(vals, 30, stacked=True, density=False, color=colors[:len(vals)])

# Decoration
plt.legend({group:col for group, col in zip(np.unique(df[groupby_var]).tolist(), colors[:len(vals)])})
plt.title(f"Stacked Histogram of Gamma Ray colored by Lithology", fontsize=22)
plt.xlabel(x_var)
plt.ylabel("Litologia")
plt.ylim(0, 6000)
plt.xlim(0, 50)
plt.xticks(ticks=bins[::3], labels=[round(b,1) for b in bins[::3]])
plt.show()

# %%
# Prepare data
x_var = 'Spontaneous_Potential'
groupby_var = 'Litologia'
newDF = (df['Litologia']=='Argille')
df_agg = df.loc[:, [x_var, groupby_var]].groupby(groupby_var)
vals = [df[x_var].values.tolist() for i, df in df_agg]
plt.rcParams['axes.facecolor'] = 'grey'
# Draw
plt.figure(figsize=(16,9), dpi= 80)
colors = [plt.cm.Spectral(i/float(len(vals)-1)) for i in range(len(vals))]
n, bins, patches = plt.hist(vals, 30, stacked=True, density=False, color=colors[:len(vals)])

# Decoration
plt.legend({group:col for group, col in zip(np.unique(df[groupby_var]).tolist(), colors[:len(vals)])})
plt.title(f"Stacked Histogram of Gamma Ray colored by Lithology", fontsize=22)
plt.xlabel(x_var)
plt.ylabel("Litologia")
plt.ylim(0, 5000)
#plt.xlim(0, 500)
plt.xticks(ticks=bins[::3], labels=[round(b,1) for b in bins[::3]])
plt.show()

# %%
# Prepare data
x_var = 'Neutron_Porosity'
groupby_var = 'Litologia'
newDF = (df['Litologia']=='Argille')
df_agg = df.loc[:, [x_var, groupby_var]].groupby(groupby_var)
vals = [df[x_var].values.tolist() for i, df in df_agg]
plt.rcParams['axes.facecolor'] = 'grey'
# Draw
plt.figure(figsize=(16,9), dpi= 80)
colors = [plt.cm.Spectral(i/float(len(vals)-1)) for i in range(len(vals))]
n, bins, patches = plt.hist(vals, 30, stacked=True, density=False, color=colors[:len(vals)])

# Decoration
plt.legend({group:col for group, col in zip(np.unique(df[groupby_var]).tolist(), colors[:len(vals)])})
plt.title(f"Stacked Histogram of Gamma Ray colored by Lithology", fontsize=22)
plt.xlabel(x_var)
plt.ylabel("Litologia")
plt.ylim(0, 2500)
#plt.xlim(0, 50)
plt.xticks(ticks=bins[::3], labels=[round(b,1) for b in bins[::3]])
plt.show()

# %%
print ('1 = Argille', '2 = Calcari', '3 = Marne', '4 = Calcari dolomitizzati', ' 5 = Dolomie')
# Out:
# 1 = Argille 2 = Calcari 3 = Marne 4 = Calcari dolomitizzati  5 = Dolomie

# %%
# Prepare Data
df = df.groupby('Litologia_Code').size()

# Make the plot with pandas
df.plot(kind='pie', subplots=False, figsize=(10, 8))
plt.title("Pie Chart of lithology ")
plt.ylabel("")
plt.show()
